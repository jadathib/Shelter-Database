# %%
from jupyter_dash import JupyterDash
# Correct import
from dash import dcc
from dash import html 
from dash import dash_table

import dash
import dash_leaflet as dl
import plotly.express as px
from dash.dependencies import Input, Output


import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from pymongo import MongoClient


#### FIX ME #####
# change animal_shelter and AnimalShelter to match your CRUD Python module file name and class name
from animal_shelter import AnimalShelter



###########################
# Data Manipulation / Model
###########################
# FIX ME update with your username and password and CRUD Python module name

username = "MyUserAdmin"
password = "trinidad1"
shelter = AnimalShelter(username, password)


# class read method must support return of cursor object and accept projection json input
df = pd.DataFrame.from_records(shelter.read({}))

print(df)





#########################
# Dashboard Layout / View
#########################
app = JupyterDash('SimpleExample')

app.layout = html.Div([
    html.Div(id='hidden-div', style={'display':'none'}),
    html.Center(html.B(html.H1('SNHU CS-340 Dashboard'))),
    html.Hr(),
    html.Div(className='row', 
            style={'display' : 'flex'}, 
                   children= [
                            html.Button(id='submit-button-one', n_clicks=0, children='Cats'), 
                            html.Button(id='submit-button-two', n_clicks=0, children='Dogs')
                   ]), 
                   
    dash_table.DataTable(
        id='datatable-interactivity',
        columns=[
            {"name": i, "id": i, "deletable": False, "selectable": True} for i in df.columns
        ],
        data=df.to_dict('records'),
        #FIXME: Set up the features for your interactive data table to make it user-friendly for your client
        editable=False, 
        filter_action="native", 
        sort_action="native", 
        sort_mode="multi", 
        column_selectable=False, 
        row_selectable=False, 
        row_deletable=False, 
        selected_columns=[], 
        selected_rows=[], 
        page_action="native", 
        page_current= 0, 
        page_size= 10,
    ),
    html.Br(),
     html.Hr(),
     html.Div(
            id='map-id',
            className='col s12 m6',
            )
])

#############################################
# Interaction Between Components / Controller
#############################################
#This callback will highlight a row on the data table when the user selects it
@app.callback(
    Output('datatable-interactivity', "data"),
    [Input('submit-button-one', 'n_clicks'), Input('submit-button-two', 'n_clicks'),]
)
def update_styles(selected_columns):
    return [{
        'if': { 'column_id': i },
        'background_color': '#D2F3FF'
    } for i in selected_columns]


@app.callback(
    Output('map-id', "children"),
    [Input('datatable-id', "derived_viewport_data"), Input('datable-id', "Look up needed attribute call for row")])
def update_map(viewData):
#FIXME Add in the code for your geolocation chart
    viewDF = pd.DataFrame.from_dict(viewData)
    dff = pd.DataFrame.from_dict(viewData)
    # Austin TX is at [30.75,-97.48]
    return [
        dl.Map(style={'width': '1000px', 'height': '500px'}, center=[30.75,-97.48], zoom=10, children=[
            dl.TileLayer(id="base-layer-id"),
            # Marker with tool tip and popup
            dl.Marker(position=[30.75,-97.48], children=[
                dl.Tooltip(dff.iloc[0,4]),
                dl.Popup([
                    html.H1("Animal Name"),
                    html.P(dff.iloc[1,9])
                ])
            ])
        ])
]
# Out:
# ---------------------------------------------------------------------------
# ServerSelectionTimeoutError               Traceback (most recent call last)
# Cell In[2], line 36
#      32 shelter = AnimalShelter(username, password)
#      35 # class read method must support return of cursor object and accept projection json input
# ---> 36 df = pd.DataFrame.from_records(shelter.read({}))
#      38 print(df)
#      44 #########################
#      45 # Dashboard Layout / View
#      46 #########################
#
# File ~\PycharmProjects\Shelter-Database\animal_shelter.py:28, in AnimalShelter.read(self, data)
#      27 def read(self,data):
# ---> 28     return self.database.animals.find_one(data)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\pymongo\synchronous\collection.py:1755, in Collection.find_one(self, filter, *args, **kwargs)
#    1753     filter = {"_id": filter}
#    1754 cursor = self.find(filter, *args, **kwargs)
# -> 1755 for result in cursor.limit(-1):
#    1756     return result
#    1757 return None
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\pymongo\synchronous\cursor.py:1281, in Cursor.__next__(self)
#    1280 def __next__(self) -> _DocumentType:
# -> 1281     return self.next()
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\pymongo\synchronous\cursor.py:1257, in Cursor.next(self)
#    1255 if self._empty:
#    1256     raise StopIteration
# -> 1257 if len(self._data) or self._refresh():
#    1258     return self._data.popleft()
#    1259 else:
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\pymongo\synchronous\cursor.py:1205, in Cursor._refresh(self)
#    1183         raise InvalidOperation(
#    1184             "Passing a 'hint' is required when using the min/max query"
#    1185             " option to ensure the query utilizes the correct index"
#    1186         )
#    1187     q = self._query_class(
#    1188         self._query_flags,
#    1189         self._collection.database.name,
#    (...)
#    1203         self._exhaust,
#    1204     )
# -> 1205     self._send_message(q)
#    1206 elif self._id:  # Get More
#    1207     if self._limit:
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\pymongo\synchronous\cursor.py:1100, in Cursor._send_message(self, operation)
#    1097     raise InvalidOperation("exhaust cursors do not support auto encryption")
#    1099 try:
# -> 1100     response = client._run_operation(
#    1101         operation, self._unpack_response, address=self._address
#    1102     )
#    1103 except OperationFailure as exc:
#    1104     if exc.code in _CURSOR_CLOSED_ERRORS or self._exhaust:
#    1105         # Don't send killCursors because the cursor is already closed.
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\pymongo\_csot.py:119, in apply.<locals>.csot_wrapper(self, *args, **kwargs)
#     117         with _TimeoutContext(timeout):
#     118             return func(self, *args, **kwargs)
# --> 119 return func(self, *args, **kwargs)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\pymongo\synchronous\mongo_client.py:1752, in MongoClient._run_operation(self, operation, unpack_res, address)
#    1742     operation.reset()  # Reset op in case of retry.
#    1743     return server.run_operation(
#    1744         conn,
#    1745         operation,
#    (...)
#    1749         self,
#    1750     )
# -> 1752 return self._retryable_read(
#    1753     _cmd,
#    1754     operation.read_preference,
#    1755     operation.session,  # type: ignore[arg-type]
#    1756     address=address,
#    1757     retryable=isinstance(operation, _Query),
#    1758     operation=operation.name,
#    1759 )
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\pymongo\synchronous\mongo_client.py:1861, in MongoClient._retryable_read(self, func, read_pref, session, operation, address, retryable, operation_id)
#    1856 # Ensure that the client supports retrying on reads and there is no session in
#    1857 # transaction, otherwise, we will not support retry behavior for this call.
#    1858 retryable = bool(
#    1859     retryable and self.options.retry_reads and not (session and session.in_transaction)
#    1860 )
# -> 1861 return self._retry_internal(
#    1862     func,
#    1863     session,
#    1864     None,
#    1865     operation,
#    1866     is_read=True,
#    1867     address=address,
#    1868     read_pref=read_pref,
#    1869     retryable=retryable,
#    1870     operation_id=operation_id,
#    1871 )
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\pymongo\_csot.py:119, in apply.<locals>.csot_wrapper(self, *args, **kwargs)
#     117         with _TimeoutContext(timeout):
#     118             return func(self, *args, **kwargs)
# --> 119 return func(self, *args, **kwargs)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\pymongo\synchronous\mongo_client.py:1828, in MongoClient._retry_internal(self, func, session, bulk, operation, is_read, address, read_pref, retryable, operation_id)
#    1791 @_csot.apply
#    1792 def _retry_internal(
#    1793     self,
#    (...)
#    1802     operation_id: Optional[int] = None,
#    1803 ) -> T:
#    1804     """Internal retryable helper for all client transactions.
#    1805
#    1806     :param func: Callback function we want to retry
#    (...)
#    1815     :return: Output of the calling func()
#    1816     """
#    1817     return _ClientConnectionRetryable(
#    1818         mongo_client=self,
#    1819         func=func,
#    1820         bulk=bulk,
#    1821         operation=operation,
#    1822         is_read=is_read,
#    1823         session=session,
#    1824         read_pref=read_pref,
#    1825         address=address,
#    1826         retryable=retryable,
#    1827         operation_id=operation_id,
# -> 1828     ).run()
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\pymongo\synchronous\mongo_client.py:2565, in _ClientConnectionRetryable.run(self)
#    2563 self._check_last_error(check_csot=True)
#    2564 try:
# -> 2565     return self._read() if self._is_read else self._write()
#    2566 except ServerSelectionTimeoutError:
#    2567     # The application may think the write was never attempted
#    2568     # if we raise ServerSelectionTimeoutError on the retry
#    2569     # attempt. Raise the original exception instead.
#    2570     self._check_last_error()
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\pymongo\synchronous\mongo_client.py:2700, in _ClientConnectionRetryable._read(self)
#    2695 def _read(self) -> T:
#    2696     """Wrapper method for read-type retryable client executions
#    2697
#    2698     :return: Output for func()'s call
#    2699     """
# -> 2700     self._server = self._get_server()
#    2701     assert self._read_pref is not None, "Read Preference required on read calls"
#    2702     with self._client._conn_from_server(self._read_pref, self._server, self._session) as (
#    2703         conn,
#    2704         read_pref,
#    2705     ):
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\pymongo\synchronous\mongo_client.py:2656, in _ClientConnectionRetryable._get_server(self)
#    2651 def _get_server(self) -> Server:
#    2652     """Retrieves a server object based on provided object context
#    2653
#    2654     :return: Abstraction to connect to server
#    2655     """
# -> 2656     return self._client._select_server(
#    2657         self._server_selector,
#    2658         self._session,
#    2659         self._operation,
#    2660         address=self._address,
#    2661         deprioritized_servers=self._deprioritized_servers,
#    2662         operation_id=self._operation_id,
#    2663     )
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\pymongo\synchronous\mongo_client.py:1647, in MongoClient._select_server(self, server_selector, session, operation, address, deprioritized_servers, operation_id)
#    1645             raise AutoReconnect("server %s:%s no longer available" % address)  # noqa: UP031
#    1646     else:
# -> 1647         server = topology.select_server(
#    1648             server_selector,
#    1649             operation,
#    1650             deprioritized_servers=deprioritized_servers,
#    1651             operation_id=operation_id,
#    1652         )
#    1653     return server
#    1654 except PyMongoError as exc:
#    1655     # Server selection errors in a transaction are transient.
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\pymongo\synchronous\topology.py:402, in Topology.select_server(self, selector, operation, server_selection_timeout, address, deprioritized_servers, operation_id)
#     392 def select_server(
#     393     self,
#     394     selector: Callable[[Selection], Selection],
#    (...)
#     399     operation_id: Optional[int] = None,
#     400 ) -> Server:
#     401     """Like select_servers, but choose a random server if several match."""
# --> 402     server = self._select_server(
#     403         selector,
#     404         operation,
#     405         server_selection_timeout,
#     406         address,
#     407         deprioritized_servers,
#     408         operation_id=operation_id,
#     409     )
#     410     if _csot.get_timeout():
#     411         _csot.set_rtt(server.description.min_round_trip_time)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\pymongo\synchronous\topology.py:380, in Topology._select_server(self, selector, operation, server_selection_timeout, address, deprioritized_servers, operation_id)
#     371 def _select_server(
#     372     self,
#     373     selector: Callable[[Selection], Selection],
#    (...)
#     378     operation_id: Optional[int] = None,
#     379 ) -> Server:
# --> 380     servers = self.select_servers(
#     381         selector, operation, server_selection_timeout, address, operation_id
#     382     )
#     383     servers = _filter_servers(servers, deprioritized_servers)
#     384     if len(servers) == 1:
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\pymongo\synchronous\topology.py:287, in Topology.select_servers(self, selector, operation, server_selection_timeout, address, operation_id)
#     284     server_timeout = server_selection_timeout
#     286 with self._lock:
# --> 287     server_descriptions = self._select_servers_loop(
#     288         selector, server_timeout, operation, operation_id, address
#     289     )
#     291     return [
#     292         cast(Server, self.get_server_by_address(sd.address)) for sd in server_descriptions
#     293     ]
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\pymongo\synchronous\topology.py:337, in Topology._select_servers_loop(self, selector, timeout, operation, operation_id, address)
#     326     if _SERVER_SELECTION_LOGGER.isEnabledFor(logging.DEBUG):
#     327         _debug_log(
#     328             _SERVER_SELECTION_LOGGER,
#     329             message=_ServerSelectionStatusMessage.FAILED,
#    (...)
#     335             failure=self._error_message(selector),
#     336         )
# --> 337     raise ServerSelectionTimeoutError(
#     338         f"{self._error_message(selector)}, Timeout: {timeout}s, Topology Description: {self.description!r}"
#     339     )
#     341 if not logged_waiting:
#     342     _debug_log(
#     343         _SERVER_SELECTION_LOGGER,
#     344         message=_ServerSelectionStatusMessage.WAITING,
#    (...)
#     350         remainingTimeMS=int(end_time - time.monotonic()),
#     351     )
#
# ServerSelectionTimeoutError: localhost:54319: [WinError 10061] No connection could be made because the target machine actively refused it (configured timeouts: socketTimeoutMS: 20000.0ms, connectTimeoutMS: 20000.0ms), Timeout: 30s, Topology Description: <TopologyDescription id: 679e69ecd12fd6fd8f521727, topology_type: Unknown, servers: [<ServerDescription ('localhost', 54319) server_type: Unknown, rtt: None, error=AutoReconnect('localhost:54319: [WinError 10061] No connection could be made because the target machine actively refused it (configured timeouts: socketTimeoutMS: 20000.0ms, connectTimeoutMS: 20000.0ms)')>]>
